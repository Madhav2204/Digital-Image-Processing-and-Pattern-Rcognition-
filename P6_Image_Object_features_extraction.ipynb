# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhav2204/Digital-Image-Processing-and-Pattern-Rcognition-/blob/main/P6_Image_Object_features_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Experiment-06**

# %% [markdown]
# ### **Image/Object features extraction**

# %% [markdown]
# ### **Feature Extraction**
# Feature extraction is a part of the dimensionality reduction process, in which, an initial set of the raw data is divided and reduced to more manageable groups. So when you want to process it will be easier. The most important characteristic of these large data sets is that they have a large number of variables.

# %% [markdown]
# ### **Method #1: Grayscale Pixel Values as Features**

# %% [markdown]
# The simplest way to create features from an image is to use these raw pixel values as separate features.
#
# Consider the same example for our image above (the number ‘8’) – the dimension of the image is 28 x 28.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Reading Image Data in Python**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread, imshow

image = imread('/content/drive/MyDrive/puppy_image_Resize.jpeg', as_gray=True)
imshow(image)

# %% [markdown]
# The image shape here is 646 x 1200. Hence, the number of features should be 775200. We can generate this using the reshape function from NumPy where we specify the dimension of the image:

# %%
#checking image shape 
image.shape, image
# Out:
# ((670, 391),
#  array([[0.96470588, 0.96470588, 0.96470588, ..., 0.96470588, 0.96470588,
#          0.96470588],
#         [0.96470588, 0.96470588, 0.96470588, ..., 0.96862745, 0.96862745,
#          0.96862745],
#         [0.96470588, 0.96470588, 0.96470588, ..., 0.96862745, 0.96862745,
#          0.96862745],
#         ...,
#         [0.96470588, 0.96470588, 0.96470588, ..., 0.96470588, 0.96470588,
#          0.96470588],
#         [0.96470588, 0.96470588, 0.96470588, ..., 0.96470588, 0.96470588,
#          0.96470588],
#         [0.96470588, 0.96470588, 0.96470588, ..., 0.96470588, 0.96470588,
#          0.96470588]]))

# %%
#pixel features

features = np.reshape(image, (670, 391))

features.shape, features
# Out:
# ((670, 391),
#  array([[0.96470588, 0.96470588, 0.96470588, ..., 0.96470588, 0.96470588,
#          0.96470588],
#         [0.96470588, 0.96470588, 0.96470588, ..., 0.96862745, 0.96862745,
#          0.96862745],
#         [0.96470588, 0.96470588, 0.96470588, ..., 0.96862745, 0.96862745,
#          0.96862745],
#         ...,
#         [0.96470588, 0.96470588, 0.96470588, ..., 0.96470588, 0.96470588,
#          0.96470588],
#         [0.96470588, 0.96470588, 0.96470588, ..., 0.96470588, 0.96470588,
#          0.96470588],
#         [0.96470588, 0.96470588, 0.96470588, ..., 0.96470588, 0.96470588,
#          0.96470588]]))

# %% [markdown]
# The image shape here is 650 x 450. Hence, the number of features should be 297,000. We can generate this using the reshape function from NumPy where we specify the dimension of the image:

# %% [markdown]
# ## Method #2: Mean Pixel Value of Channels
# While reading the image in the previous section, we had set the parameter ‘as_gray = True’. So we only had one channel in the image and we could easily append the pixel value

# %%
image = imread('/content/drive/MyDrive/puppy_image_Resize.jpeg') 
image.shape
# Out:
# (670, 391, 3)

# %%
image = imread('/content/drive/MyDrive/puppy_image_Resize.jpeg')
feature_matrix = np.zeros((670, 391)) 
feature_matrix.shape
# Out:
# (670, 391)

# %% [markdown]
# We have a 3D matrix of dimension (646 x 1200 x 3) where 646 is the height, 1200 is the width and 3 is the number of channels. To get the average pixel values, we will use a for loop:

# %%
for i in range(0,image.shape[0]):
    for j in range(0,image.shape[1]):
        feature_matrix[i][j] = ((int(image[i,j,0]) + int(image[i,j,1]) + int(image[i,j,2]))/3)

# %%
features = np.reshape(feature_matrix, (670 * 391)) 
features.shape
# Out:
# (261970,)

# %% [markdown]
# The new matrix will have the same height and width but only 1 channel. Now we can follow the same steps that we did in the previous section. We append the pixel values one after the other to get a 1D array:

# %% [markdown]
# ### **Method #3: Extracting Edge Features**

# %%
#importing the required libraries
import numpy as np
from skimage.io import imread, imshow
from skimage.filters import prewitt_h,prewitt_v
import matplotlib.pyplot as plt
# %matplotlib inline

#reading the image 
image = imread('/content/drive/MyDrive/puppy_image_Resize.jpeg',as_gray=True)

#calculating horizontal edges using prewitt kernel
edges_prewitt_horizontal = prewitt_h(image)
#calculating vertical edges using prewitt kernel
edges_prewitt_vertical = prewitt_v(image)

imshow(edges_prewitt_vertical, cmap='gray')

# %% [markdown]
# ## **Submitted By : Madhav Shrivastava**
#
# ## **Enroll no.   : 19100BTCSBS05597**
